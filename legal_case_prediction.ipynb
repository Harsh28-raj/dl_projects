# %% [markdown]
# <a href="https://colab.research.google.com/github/Harsh28-raj/dl_projects/blob/main/legal_case_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p ~/.kaggle

# !cp kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !pip install kaggle

# %%
# !kaggle datasets download -d vangap/indian-supreme-court-judgments
# Out:
# Dataset URL: https://www.kaggle.com/datasets/vangap/indian-supreme-court-judgments
# License(s): CC-BY-NC-SA-4.0
# ...
# 100% 4.75G/4.77G [03:54<00:00, 111MB/s]
# 100% 4.77G/4.77G [03:54<00:00, 21.9MB/s]

# %%
# !unzip indian-supreme-court-judgments.zip judgments.csv
# Out:
# Archive:  indian-supreme-court-judgments.zip
#   inflating: judgments.csv

# %%
import pandas as pd

df=pd.read_csv("judgments.csv")

df.head()
# Out:
#    diary_no Judgement_type                          case_no  \
# 0    5-2021              J                 MA-000083 - 2021
# 1   28-2021              J    C.A. No.-000867-000867 - 2021
# 2   70-2020              J  Crl.A. No.-000167-000167 - 2021
# 3   82-2021              J         SLP(C) No.-000811 - 2021
# 4  114-2021              J    C.A. No.-000390-000390 - 2021
#
#                                                  pet  \
# 0                                     UNION OF INDIA
# 1  INDEX MEDICAL COLLEGE HOSPITAL AND RESEARCH CE...
# 2                                       ARCHANA RANA
# 3          THE EMPLOYEES STATE INSURANCE CORPORATION
# 4  KALOJI NARAYANA RAO UNIVERSITY OF HEALTH SCIENCES
#
#                                                  res  \
# 0  ASSOCIATION OF UNIFIED TELECOM SERVICEPROVIDER...
# 1                        THE STATE OF MADHYA PRADESH
# 2                         THE STATE OF UTTAR PRADESH
# 3                              M/S. TEXMO INDUSTRIES
# ...

# %%
# !rm indian-supreme-court-judgments.zip

# %%
df.sample(1000)
# Out:
#        case_type  lawyer_exp  judge_exp  judge_count  complexity  evidence  \
# 23952          0      0.0900   1.000000          4.0        20.0  0.698842
# 2197           1      0.0850   0.180339          2.0        19.0  0.693684
# 833            1      0.0525   0.077966          3.0        20.0  0.517479
# 25403          0      0.0075   0.077288          3.0        17.0  0.793576
# 23172          0      0.0250   0.086102          3.0        24.0  0.576273
# ...          ...         ...        ...          ...         ...       ...
# 23197          0      0.2200   0.077966          3.0        17.0  0.893389
# 22517          1      0.0425   0.576271          3.0        18.0  0.552169
# 532            1      0.0400   0.149831          3.0        21.0  0.795089
# 22404          0      0.0375   0.046102          3.0        22.0  0.519790
# 22898          1      0.0425   0.034576          3.0        11.0  0.461696
#
#        outcome
# 23952        1
# 2197         0
# 833          0
# ...

# %%
df.shape
# Out:
# (8094, 7)

# %%
df.columns
# Out:
# Index(['case_type', 'lawyer_exp', 'judge_exp', 'judge_count', 'complexity',
#        'evidence', 'outcome'],
#       dtype='object')

# %%
df=df.drop([
'diary_no',
'Judgement_type',
'pet',
'res',
'res_adv',
'temp_link',
'language'
],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_287/287400828.py in <cell line: 0>()
# ----> 1 df=df.drop([
#       2 'diary_no',
#       3 'Judgement_type',
#       4 'pet',
#       5 'res',
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df.head()
# Out:
#        case_type  lawyer_exp  judge_exp  judge_count  complexity  evidence  \
# 611            0      0.0250   0.050847          4.0        26.0  0.595104
# 858            1      0.0125   0.027119          3.0        11.0  0.445375
# 861            1      0.0150   0.027119          3.0        17.0  0.623358
# 22221          1      0.0225   0.022373          3.0        20.0  0.858523
# 2232           1      0.0225   0.044746          3.0        21.0  0.478787
#
#        outcome
# 611          0
# 858          0
# 861          1
# 22221        0
# 2232         0

# %%
df.dropna()
# Out:
#        case_type  lawyer_exp  judge_exp  judge_count  complexity  evidence  \
# 611            0      0.0250   0.050847          4.0        26.0  0.595104
# 858            1      0.0125   0.027119          3.0        11.0  0.445375
# 861            1      0.0150   0.027119          3.0        17.0  0.623358
# 22221          1      0.0225   0.022373          3.0        20.0  0.858523
# 2232           1      0.0225   0.044746          3.0        21.0  0.478787
# ...          ...         ...        ...          ...         ...       ...
# 25043          1      1.0000   1.000000          3.0        15.0  0.864345
# 25167          1      1.0000   1.000000          3.0        17.0  0.791425
# 2077           1      1.0000   1.000000          3.0        16.0  0.520378
# 9256           1      1.0000   1.000000          3.0        19.0  0.413050
# 24594          1      1.0000   1.000000          3.0        21.0  0.456649
#
#        outcome
# 611          0
# 858          0
# 861          1
# ...

# %%
df.shape
# Out:
# (8094, 7)

# %%
df.head()
# Out:
#        case_type  lawyer_exp  judge_exp  judge_count  complexity  evidence  \
# 611            0      0.0250   0.050847          4.0        26.0  0.595104
# 858            1      0.0125   0.027119          3.0        11.0  0.445375
# 861            1      0.0150   0.027119          3.0        17.0  0.623358
# 22221          1      0.0225   0.022373          3.0        20.0  0.858523
# 2232           1      0.0225   0.044746          3.0        21.0  0.478787
#
#        outcome
# 611          0
# 858          0
# 861          1
# 22221        0
# 2232         0

# %%
def get_case_type(x):

    x=str(x)

    if "Crl" in x:
        return 0

    elif "C.A" in x:
        return 1

    elif "SLP" in x:
        return 2

    elif "W.P" in x:
        return 3

    else:
        return 4

df['case_type']=df['case_no'].apply(get_case_type)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'case_no'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_287/1595242897.py in <cell line: 0>()
#      18         return 4
#      19
# ...

# %%
df.head()
# Out:
#        case_type  lawyer_exp  judge_exp  judge_count  complexity  evidence  \
# 611            0      0.0250   0.050847          4.0        26.0  0.595104
# 858            1      0.0125   0.027119          3.0        11.0  0.445375
# 861            1      0.0150   0.027119          3.0        17.0  0.623358
# 22221          1      0.0225   0.022373          3.0        20.0  0.858523
# 2232           1      0.0225   0.044746          3.0        21.0  0.478787
#
#        outcome
# 611          0
# 858          0
# 861          1
# 22221        0
# 2232         0

# %%
lawyer_counts=df['pet_adv'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pet_adv'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_287/2816665923.py in <cell line: 0>()
# ----> 1 lawyer_counts=df['pet_adv'].value_counts()
#       2
#
# ...

# %%
df['lawyer_exp']=df['pet_adv'].map(lawyer_counts)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pet_adv'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_287/2243574843.py in <cell line: 0>()
# ----> 1 df['lawyer_exp']=df['pet_adv'].map(lawyer_counts)
#
# ...

# %%
df['lawyer_exp']=df['lawyer_exp']/df['lawyer_exp'].max()

# %%
judge_counts=df['judgement_by'].value_counts()

df['judge_exp']=df['judgement_by'].map(judge_counts)

df['judge_exp']=df['judge_exp']/df['judge_exp'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'judgement_by'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_287/2167742344.py in <cell line: 0>()
# ----> 1 judge_counts=df['judgement_by'].value_counts()
#       2
# ...

# %%
df['judge_count']=df['bench'].str.count("JUSTICE")+1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'bench'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_287/4223188903.py in <cell line: 0>()
# ----> 1 df['judge_count']=df['bench'].str.count("JUSTICE")+1
#
# ...

# %%
df['year']=df['judgment_dates'].str[-4:]

df['year']=pd.to_numeric(df['year'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'judgment_dates'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_287/2598028715.py in <cell line: 0>()
# ----> 1 df['year']=df['judgment_dates'].str[-4:]
#       2
# ...

# %%
df['year']=df['year']/df['year'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_287/1903184119.py in <cell line: 0>()
# ----> 1 df['year']=df['year']/df['year'].max()
#
# ...

# %%
import numpy as np

df['complexity']=(
df['judge_count']*2+
np.random.randint(5,20,len(df))
)

# %%
df['evidence']=np.random.uniform(0.4,0.9,len(df))

# %%
df['win_score']=(
0.30*df['lawyer_exp']+
0.30*df['judge_exp']+
0.20*df['evidence']+
0.20*(1/(df['complexity']/10))
)

# %%
df['outcome'] = np.random.binomial(1, df['win_score'])

# %%
df=df[[

'case_type',
'lawyer_exp',
'judge_exp',
'judge_count',
'complexity',
'evidence',
'outcome'

]]

# %%
df.head()
# Out:
#        case_type  lawyer_exp  judge_exp  judge_count  complexity  evidence  \
# 611            0      0.0250   0.050847          4.0        14.0  0.708841
# 858            1      0.0125   0.027119          3.0        18.0  0.711978
# 861            1      0.0150   0.027119          3.0        21.0  0.864992
# 22221          1      0.0225   0.022373          3.0        24.0  0.705451
# 2232           1      0.0225   0.044746          3.0        17.0  0.737740
#
#        outcome
# 611          1
# 858          0
# 861          0
# 22221        0
# 2232         1

# %%
df.describe()
# Out:
#          case_type   lawyer_exp    judge_exp  judge_count   complexity  \
# count  8094.000000  8094.000000  8094.000000  8094.000000  8094.000000
# mean      0.955523     0.119956     0.317675     3.194836    18.385100
# std       0.925228     0.172536     0.338897     0.470526     4.417071
# min       0.000000     0.002500     0.000678     2.000000     9.000000
# 25%       0.000000     0.022500     0.090169     3.000000    15.000000
# 50%       1.000000     0.057500     0.151186     3.000000    18.000000
# 75%       1.000000     0.137500     0.576271     3.000000    22.000000
# max       4.000000     1.000000     1.000000     6.000000    31.000000
#
#           evidence      outcome
# count  8094.000000  8094.000000
# mean      0.650976     0.375834
# std       0.143624     0.484367
# min       0.400019     0.000000
# 25%       0.525895     0.000000
# 50%       0.651609     0.000000
# 75%       0.774056     1.000000
# max       0.899965     1.000000

# %%
X=df.drop("outcome",axis=1)

y=df["outcome"]

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

model=RandomForestClassifier(
n_estimators=200
)

model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
from sklearn.metrics import accuracy_score

pred=model.predict(X_test)

print("Accuracy:",
accuracy_score(y_test,pred))
# Out:
# Accuracy: 0.6158122297714639

# %%
sample=X_test.iloc[0:1]

prob=model.predict_proba(sample)

print("Win probability:",
round(prob[0][1]*100,2),"%")

print("Loss probability:",
round(prob[0][0]*100,2),"%")
# Out:
# Win probability: 27.5 %
# Loss probability: 72.5 %

# %%
for i in range(5):

    sample=X_test.iloc[i:i+1]

    prob=model.predict_proba(sample)

    print("Case",i)

    print("Win:",
    round(prob[0][1]*100,2),"%")

    print("Lose:",
    round(prob[0][0]*100,2),"%")

    print()
# Out:
# Case 0
# Win: 27.5 %
# Lose: 72.5 %
#
# Case 1
# Win: 42.0 %
# Lose: 58.0 %
#
# Case 2
# Win: 39.0 %
# Lose: 61.0 %
#
# Case 3
# Win: 45.0 %
# Lose: 55.0 %
#
# Case 4
# Win: 22.5 %
# Lose: 77.5 %

# %%
df = df.sort_values('win_score')

df['outcome'] = 0

df.iloc[len(df)//2:, df.columns.get_loc('outcome')] = 1

df['outcome'] = df['outcome'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_287/153024687.py in <cell line: 0>()
# ----> 1 df = df.sort_values('win_score')
#       2
#       3 df['outcome'] = 0
#       4
#       5 df.iloc[len(df)//2:, df.columns.get_loc('outcome')] = 1
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
# ...

# %%
df["outcome"].value_counts()

# %%
df['outcome'].value_counts(normalize=True)

# %%
df.head()

# %%
df['win_score'].describe()

# %%
df['outcome'].value_counts(normalize=True)

# %%
df=df.dropna()
df=df.drop_duplicates()

# %%
df.head()

# %%
df = df.drop(['complexity','evidence','win_score'], axis=1)

# %%
X = X.fillna(0)

# %%
prob=model.predict_proba(X_test)

# %%
df.head()

# %%
X=df[['case_type','lawyer_exp','judge_exp','judge_count']]

# %%
y=df['outcome']

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
scaler=StandardScaler()

X=scaler.fit_transform(X)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

model=LogisticRegression(max_iter=2000)

model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=2000)

# %%
print(y.value_counts())

print(y_train.value_counts())

print(y_test.value_counts())
# Out:
# outcome
# 0    5052
# 1    3042
# Name: count, dtype: int64
# outcome
# 0    4067
# 1    2408
# Name: count, dtype: int64
# outcome
# 0    985
# 1    634
# Name: count, dtype: int64

# %%
df['complexity']=( df['judge_count']*2 + np.random.randint(5,20,len(df)) )

df['evidence']=np.random.uniform(0.4,0.9,len(df))

df['win_score']=(
0.30*df['lawyer_exp']+
0.30*df['judge_exp']+
0.20*df['evidence']+
0.20*(1/(df['complexity']/10))
)
# Out:
# /tmp/ipykernel_287/877564409.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['complexity']=( df['judge_count']*2 + np.random.randint(5,20,len(df)) )
# /tmp/ipykernel_287/877564409.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['evidence']=np.random.uniform(0.4,0.9,len(df))

# %%
df = df.sort_values('win_score')

df['outcome']=0

df.iloc[len(df)//2: , df.columns.get_loc('outcome')] = 1

# %%
FEATURES=['case_type','lawyer_exp','judge_exp','judge_count']

X=df[FEATURES]

y=df['outcome']

# %%
print(y.value_counts())
# Out:
# outcome
# 0    4047
# 1    4047
# Name: count, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(
X,y,test_size=0.2,stratify=y)

# %%
scaler=StandardScaler()

X_train=scaler.fit_transform(X_train)

X_test=scaler.transform(X_test)

# %%
from sklearn.calibration import CalibratedClassifierCV

model = LogisticRegression(max_iter=2000)

calibrated = CalibratedClassifierCV(model, method='sigmoid')

calibrated.fit(X_train,y_train)
# Out:
# CalibratedClassifierCV(estimator=LogisticRegression(max_iter=2000))

# %%
prob = calibrated.predict_proba(sample)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_287/385818014.py in <cell line: 0>()
# ----> 1 prob = calibrated.predict_proba(sample)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/calibration.py in predict_proba(self, X)
#     499         mean_proba = np.zeros((_num_samples(X), len(self.classes_)))
#     500         for calibrated_classifier in self.calibrated_classifiers_:
# --> 501             proba = calibrated_classifier.predict_proba(X)
#     502             mean_proba += proba
#     503
#
# /usr/local/lib/python3.12/dist-packages/sklearn/calibration.py in predict_proba(self, X)
#     723             The predicted probabilities. Can be exact zeros.
# ...

# %%
model = LogisticRegression(
max_iter=2000,
C=0.3
)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

print(classification_report(y_test,pred))

print(confusion_matrix(y_test,pred))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /tmp/ipykernel_287/2938977701.py in <cell line: 0>()
#       1 from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
#       2
# ----> 3 pred=model.predict(X_test)
#       4
#       5 print("Accuracy:",accuracy_score(y_test,pred))
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     372         """
#     373         xp, _ = get_namespace(X)
# --> 374         scores = self.decision_function(X)
#     375         if len(scores.shape) == 1:
#     376             indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     346             this class would be predicted.
#     347         """
# --> 348         check_is_fitted(self)
# ...

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

pred=model.predict(X_test)

print("Accuracy:",accuracy_score(y_test,pred))

print(classification_report(y_test,pred))

print(confusion_matrix(y_test,pred))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /tmp/ipykernel_287/2938977701.py in <cell line: 0>()
#       1 from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
#       2
# ----> 3 pred=model.predict(X_test)
#       4
#       5 print("Accuracy:",accuracy_score(y_test,pred))
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     372         """
#     373         xp, _ = get_namespace(X)
# --> 374         scores = self.decision_function(X)
#     375         if len(scores.shape) == 1:
#     376             indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     346             this class would be predicted.
#     347         """
# --> 348         check_is_fitted(self)
# ...

# %%
prob=model.predict_proba(X_test)

win_prob=prob[:,1]

print(win_prob[:10])
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /tmp/ipykernel_287/1262771427.py in <cell line: 0>()
# ----> 1 prob=model.predict_proba(X_test)
#       2
#       3 win_prob=prob[:,1]
#       4
#       5 print(win_prob[:10])
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py in predict_proba(self, X)
#    1419             where classes are ordered as they are in ``self.classes_``.
#    1420         """
# -> 1421         check_is_fitted(self)
#    1422
#    1423         ovr = self.multi_class in ["ovr", "warn"] or (
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1755
#    1756     if not _is_fitted(estimator, attributes, all_or_any):
# -> 1757         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1758
#    1759
#
# ...

# %%
import numpy as np

def predict_case(case_type,lawyer_exp,judge_exp,judge_count):

    FEATURES=['case_type','lawyer_exp','judge_exp','judge_count']

    sample=np.array([[case_type,lawyer_exp,judge_exp,judge_count]])

    sample=scaler.transform(sample)

    prob=model.predict_proba(sample)

    win=prob[0][1]*100

    if win>70:
        strength="Strong"

    elif win>50:
        strength="Moderate"

    else:
        strength="Weak"

    return {
        "win_probability":round(win,2),
        "case_strength":strength
    }

# %%
predict_case(1,0.3,0.5,3)

# %%
importance=model.coef_[0]

for i,v in enumerate(importance):
    print(FEATURES[i],":",v)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_287/2232038905.py in <cell line: 0>()
# ----> 1 importance=model.coef_[0]
#       2
#       3 for i,v in enumerate(importance):
#       4     print(FEATURES[i],":",v)
#
# AttributeError: 'LogisticRegression' object has no attribute 'coef_'

# %%
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier(
    n_estimators=300,
    max_depth=10,
    random_state=42
)

rf.fit(X_train,y_train)

rf_pred=rf.predict(X_test)

print("RF Accuracy:",accuracy_score(y_test,rf_pred))
# Out:
# RF Accuracy: 0.8616429894996912

# %%
# !pip install xgboost

# %%
from xgboost import XGBClassifier

xgb=XGBClassifier(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=6,
    random_state=42
)

xgb.fit(X_train,y_train)

xgb_pred=xgb.predict(X_test)

print("XGB Accuracy:",accuracy_score(y_test,xgb_pred))
# Out:
# XGB Accuracy: 0.8591723285978999

# %%
prob=xgb.predict_proba(X_test)

print(prob[:5])
# Out:
# [[4.2599440e-04 9.9957401e-01]
#  [9.4189942e-01 5.8100559e-02]
#  [9.6201897e-04 9.9903798e-01]
#  [9.9721527e-01 2.7847202e-03]
#  [4.1675591e-01 5.8324409e-01]]

# %%
from sklearn.metrics import accuracy_score

# Logistic
log_pred=model.predict(X_test)
accuracy1=accuracy_score(y_test,log_pred)

# Random Forest
rf_pred=rf.predict(X_test)
accuracy2=accuracy_score(y_test,rf_pred)

# XGBoost
xgb_pred=xgb.predict(X_test)
accuracy3=accuracy_score(y_test,xgb_pred)

results={
"Logistic":accuracy1,
"RandomForest":accuracy2,
"XGBoost":accuracy3
}

print(results)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /tmp/ipykernel_287/1200622702.py in <cell line: 0>()
#       2
#       3 # Logistic
# ----> 4 log_pred=model.predict(X_test)
#       5 accuracy1=accuracy_score(y_test,log_pred)
#       6
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     372         """
#     373         xp, _ = get_namespace(X)
# --> 374         scores = self.decision_function(X)
#     375         if len(scores.shape) == 1:
#     376             indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     346             this class would be predicted.
#     347         """
# --> 348         check_is_fitted(self)
#     349         xp, _ = get_namespace(X)
#     350
#
# ...

# %%
for model_name,acc in results.items():
    print(model_name,"Accuracy:",round(acc*100,2),"%")

# %%
from sklearn.metrics import classification_report

print("Logistic")
print(classification_report(y_test,log_pred))

print("Random Forest")
print(classification_report(y_test,rf_pred))

print("XGBoost")
print(classification_report(y_test,xgb_pred))

# %%
FEATURES=['case_type','lawyer_exp','judge_exp','judge_count']

importance=model.coef_[0]

for i,v in enumerate(importance):
    print(FEATURES[i],":",round(v,3))

# %%
def predict_case(case_type,lawyer_exp,judge_exp,judge_count):

    sample=np.array([[case_type,lawyer_exp,judge_exp,judge_count]])

    sample=scaler.transform(sample)

    prob=model.predict_proba(sample)

    win=prob[0][1]*100

    if win>70:
        strength="Strong"

    elif win>50:
        strength="Moderate"

    else:
        strength="Weak"

    return {
        "Win probability":round(win,2),
        "Case strength":strength
    }

# %%
predict_case(1,0.3,0.5,3)

# %%
import pickle

pickle.dump(model,open("legal_case_model.pkl","wb"))

pickle.dump(scaler,open("scaler.pkl","wb"))

# %%
for i in range(10):

    print(predict_case(
        np.random.randint(0,4),
        np.random.uniform(0,1),
        np.random.uniform(0,1),
        np.random.randint(1,5)
    ))

# %%
pred=model.predict(X_test)

print(np.unique(pred,return_counts=True))

# %%
predict_case(0,0.01,0.02,1)

# %%
predict_case(1,0.02,0.01,1)

# %%
predict_case(2,0.05,0.03,1)

# %%
import pandas as pd
import numpy as np

FEATURES=['case_type','lawyer_exp','judge_exp','judge_count']

def predict_case(case_type,lawyer_exp,judge_exp,judge_count):

    sample=pd.DataFrame(
        [[case_type,lawyer_exp,judge_exp,judge_count]],
        columns=FEATURES
    )

    sample=scaler.transform(sample)

    prob=model.predict_proba(sample)

    win=float(prob[0][1]*100)

    if win>70:
        strength="Strong"
    elif win>50:
        strength="Moderate"
    else:
        strength="Weak"

    return {
        "Win probability":round(win,2),
        "Case strength":strength
    }
